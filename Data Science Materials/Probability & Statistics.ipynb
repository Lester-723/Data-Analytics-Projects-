# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import scipy.stats
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Expected values
#
# > The expected value of an event is the outcome we expect to occur when we run an experiment.
#
# > **<font color = "yellow">The expected value of an event is the probability of the outcome multiplied by the number of trials (which means the number of times we run the experiment).</font>**
#
# > `A trial produces one and only one outcome.`
#
# > An experiment is a collection of trials. In other words, performing a trial multiple times.
#
# > We use intervals in forecasting events because there is a low probability of the success of the expected value. Intervals also increase the likelihood of the predictions being true.
#
# ---
#
# ### Complements
#
# > The complement of the complement is the event itself.
#
# > The probability of a complement is $1 -$ the event itself: $P(A') = 1- P(A)$
#
# > **eg: Probability of getting a 3 on a die is $1/6 = P(A)$**
#
# > **The probability of not getting a 3 is $1-1/6 = 5/6 = P(A')$**
#
# > **<font color = "yellow">A complement is the inverse of the event. In other words, a complement is an event not happening.</font>**
#
# > ***Complement events can never occur simultaneously or at the same time. In other words, one event occurs if the other does not take place. In the example of the die, for the probability of getting 1,2,4,5,6 to occur, the probability of 3 should not occur.***

# %% [markdown]
# ### WHY DO WE USE $P(A) + P(B) - P(A \cap B)$?
#
# > When we want to know the chance that either event A happens, or event B happens (or both), we use this formula:
# >
# > $$
# > P(A \text{ or } B) = P(A) + P(B) - P(A \cap B)
# > $$
# >
# > - $P(A)$ is the probability that event A happens.
# > - $P(B)$ is the probability that event B happens.
# > - If we simply add $P(A)$ and $P(B)$, we accidentally count the times when both A and B happen together twice.
# > - To correct this, we subtract $P(A \cap B)$, which is the probability that both A and B happen at the same time.
# >
# > **Simple Example:**
# > Imagine you have a group of children:
# > - 5 like apples (A)
# > - 4 like bananas (B)
# > - 2 like both apples and bananas (A and B)
# >
# > If you count all the apple lovers and all the banana lovers, you count the children who like both twice. So, you subtract the number who like both to get the correct total:
# >
# > $$
# > P(A \text{ or } B) = P(A) + P(B) - P(A \cap B)
# > $$
# >
# > This way, you only count each child once!
# >
# > **In summary:**
# > We use this formula to avoid double-counting when events can happen at the same time.

# %% [markdown]
# ## Combinatorics
# > use `itertools` with permutations or combinations methods
#
# ### Permutations
#
# > **`The number of different possible ways we can arrange a set of elements. Basically considering different situations where events can happen`**
#
# > Permutations and combinations are associated with `fatorials`
#
# > Considering a factorial of 3 will be 6 because 3! = 1 * 2 * 3 = 6. In other words for an event of size 3 there are 6 possible ways to arrange it. eg: 3 medalists can be arranged in 6 different ways
# >> Mike can get gold , Sean and Paul can get either get silver or bronze
# >> Sean can get gold , Mike and Paul can get either get silver or bronze
# >> Paul can get gold , Mike and Sean can get either get silver or bronze
#
# > In the above situations , there are two ways things can either one gets silver or bronze ,so considering all the possible situations ( 3 situations) with the possible outcome we can it is 3!
#
# > Using the `math` package along with the factorial function we can calculate the factorial of the number
#
# ### Variations
#
# > Variations are permutations with restrictions
#
# > `Even though the order matters there are restrictions`
#
# ### Variations with repitition
#
# > Given we have to solve a lock to solve without knowing the correct code. Logically the lock can have the same numbers repeating.
#
# > We can fill numbers from 0 to 9 to fill 3 positions in the lock
#
# > So the number of possible variations we have to solve is denoted by the **`number of options` to the power of `number of positions`**
#
# > In the problem we can get 10**3 possible variations which also involves `reusing the same number in the 3 given positions`
#
# ### Variations without repitition
#
# > Given the example of a relay. There cannot be a runner running two positions in a relay. So no repition basically
#
# > So in order to account for no repitition for calculating the possible variations
#
# > **`n!/(n-p)!`**

# %% [markdown]
# ### Combinations
#
# > The difference between permutations and combination is that **`Permutations give more emphasis on the order of the objects being arranged while combinations do not.`**
#
# > In simple words **`Permutations are arrangements where order of objects matters and Combinations are arrangements where order does not matter`**
#
# > **`Order is irrelevant in combinations in whichever example we take`**
#
# > Since Combinations don't care about the order, **`double counting is not allowed`**. Eg : AB and BA are the same. but in permuations they are different becuase the order in which they were arranged was different.
#
# > **`Variations are permutations which are bound by certain restrictions like in the case of the specific no. of postions to be filled with multiple options.`**
#
#
# > Formula of combinations - **`n!/p!(n-p)!`**
#
# > > Formula of combinations with repitition - **`(n+p -1)!/p!(n-1)!`**
#
# > **<font color = "yellow"> There are different permutations or different orders of a single combination are different variations </font>**
#
# > ***Given 10 people we can form a group of 3. So we can create 120 combinations of that group(no double counting). Each group can have be arranged in a different order 6 times. So given 120 combinations with combination have 6 ways in which each group can be arranged which gives rise to 720 variations of the groups (120 * 6)***
#
# > OR combinations = Variations/ permutations
#
# > **`Picking more elements to form a combination leads to fewer combinations`**
#
# ### Symmetry of combinations
#
# > **`While formaing a group of 3 from 10. We chose to leave the rest of the 7 behind. It is the same as leaving 7 behind and choosing 3`**
#
# > **`Basically while making a combination of a certain size from many options , we choose to omit a specific number of options to make a combination`**

# %% [markdown]
# ### Combinations of different sample spaces
#
# > Given an example of a restaurant with a menu of 3 dishes - Main menu, sides and drinks, these 3 menus are individual invents
#
# >> If the main menu has 5 different dishes , sides have 4 dishes  and drinks 2 dishes then the possible combinations would be 5 times 4 times 2 = 40
#
# >> **Here we are considering the fact that each position of `p` has its individual sample spaces from the example**
#
# >> **`In other words, calculating the total number of combinations is by multiplying the number of options available in each individual event`**

# %% [markdown]
# ![image.png](attachment:image.png)
#
# > Given in the example the probability of someone being a vegetarian is the P(being a vegetarian who is a male)*P(being a male) + P(being a vegetarian who is a female)*P(being a female)
#
# > 29/44*53/100 + 15/47 * 47/100 = 0.44

# %% [markdown]
# ### Additive and Multiplicative Rules of Probability
#
# - **Additive Rule:**
#   - The additive rule is used to find the probability that at least one of two events occurs (i.e., the probability of the union of two events).
#   - For two mutually exclusive (disjoint) events A and B:
#     $$
#     P(A \text{ or } B) = P(A) + P(B)
#     $$
#   - For events that are not mutually exclusive:
#     $$
#     P(A \text{ or } B) = P(A) + P(B) - P(A \cap B)
#     $$
#   - **Use this rule when you want the probability that either event A or event B happens.**
#
# - **Multiplicative Rule:**
#   - The multiplicative rule is used to find the probability that two events both occur (i.e., the probability of the intersection of two events).
#   - For independent events A and B:
#     $$
#     P(A \text{ and } B) = P(A) \times P(B)
#     $$
#   - For dependent events:
#     $$
#     P(A \text{ and } B) = P(A) \times P(B|A)
#     $$
#   - **Use this rule when you want the probability that both event A and event B happen together.**
#
# We use these rules to calculate probabilities for combined events, helping us understand the likelihood of one or more events happening in various situations.
#
# ---
#
# ### Difference Between Additive and Multiplicative Rules (with Example):
#
# - The additive rule is used for the probability of either event happening (union), while the multiplicative rule is used for the probability of both events happening together (intersection).
#
# **Example (Additive Rule):**
# Suppose you roll a die.
# - Let event A be getting an even number (2, 4, 6). $P(A) = 3/6 = 0.5$
# - Let event B be getting a number greater than 4 (5, 6). $P(B) = 2/6 \approx 0.33$
# - Numbers that are even or greater than 4: 2, 4, 5, 6 (4 outcomes)
# - $P(A \text{ or } B) = 4/6 \approx 0.67$
#
# **Example (Multiplicative Rule - Independent Events):**
# Suppose you toss a coin and roll a die.
# - Probability of getting a head ($P(H)$) = $1/2$
# - Probability of getting a 4 on the die ($P(4)$) = $1/6$
# - The events are independent, so:
# $$
# P(H \text{ and } 4) = P(H) \times P(4) = 1/2 \times 1/6 = 1/12
# $$
#
# **Example (Multiplicative Rule - Dependent Events):**
# Suppose in a class, 60% of students are boys ($P(B) = 0.6$). Among boys, 30% play football ($P(F|B) = 0.3$).
# - Probability that a student is a boy and plays football:
# $$
# P(B \text{ and } F) = P(B) \times P(F|B) = 0.6 \times 0.3 = 0.18
# $$
#
# ---
#
# ### Example: Probability of Being Male and Vegetarian
#
# Suppose in a city, 60% of the population is male ($P(\text{Male}) = 0.6$). Among males, 30% are vegetarians ($P(\text{Vegetarian} \mid \text{Male}) = 0.3$).
#
# To find the probability that a randomly selected person is both male and vegetarian:
#
# $$
# P(\text{Male and Vegetarian}) = P(\text{Male}) \times P(\text{Vegetarian} \mid \text{Male}) = 0.6 \times 0.3 = 0.18
# $$
#
# So, there is an 18% chance that a randomly selected person is both male and vegetarian.
#
# This probability is also called the intersection of the two events: being male and being vegetarian, written as $P(\text{Male} \cap \text{Vegetarian})$.

# %% [markdown]
# ### Mutually exclusive and independant events
#
# > They are not the same
#
# > `Mutually exclusive events` are events that  have no two events happening at the same time. In other words if we have one event where students play basketball and another event where students play football there cannot be an event where students play both at the same time.there is no intersection between two events or in other words the `probabilty of students playing both sports at the same time is 0`
#
# > **`Since mutually exclusive events or sets are sets or events that don't happen at the same time that means their intersection is 0 or a null set`**
#
# >Mutually exclusive events cannot occur simultaneously, so the probability of both events happening together is 0.
#
# > Basically if one event occurs then the other can't
#
# > Independent events have no influence on each other, so the probability of both events happening together is equal to the product of their individual probabilities.
#
# > The probability of two independent events happening simultaneously or at the same time is the product of the two individual probabilities
#
# > `Event A and Event B are mutually exclusive if P(A intersection B) = 0`
#
# > `Event A and Event B are independant events if P(A) = P(A|B)` Applying the condition B does not affect the probability of A
# or `P(B) = P(B|A)` Applying the condition A does not affect the probability of B. <u>To summarize the probability of obatining an outcome A does not affect the probability of obtaining the outcome B</u>
#
# > **`Probability of A given B has occurred != Probability of B given A has occured`**

# %% [markdown]
# ### Bayes Theoram (Basis for the Naives Bayes Classifier)
#
# > Bayes’ Theorem is based on conditional probability — it helps us find the probability of one event given that another event has already happened.
#
# > It allows us to update our beliefs or predictions as we get new information or evidence.
#
# > The Naive Bayes Classifier applies this concept to predict which category something belongs to — it calculates the probability of each class given certain features or conditions.
#
# > It’s called “naive” because it assumes all features are independent events, meaning the occurrence of one feature does not affect the occurrence of another (for example, the presence of one word in an email doesn’t influence another).
#
# > Even with this simple assumption, Naive Bayes is fast, effective, and widely used — especially for spam detection, text classification, and sentiment analysis.

# %% [markdown]
# ## Probability density functions
#
# > `In a distribution the more congested the middle of the distribution, the more data falls within tha interval`
#
# > `The less data that falls in the interval  the more spread out or dispersed the data is`
#
# > It consists of the following:
# 1. Probability density function (pdf)
# 2. Probability mass function (pmf)
# 3. Cummulative distributive function (cdf)
# 4. Percent point function (ppf)
#
#
# > Probability density function is used with continous variables like height and weight
#
# > Probability mass function is used with discrete variables like eg : no. of dice rolls (from 1 to 6)
#
# > Cummulative distributive function is a cummulative probability function
#
# > Percent point function is the inverse of the cummulative density function

# %% [markdown]
# ## Probability mass function and Cummalative distributive function (discrete)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# > **In the context of the above image, probability of rolling a 4 or less in cdf is = to the probability of 1,2,3 and 4 in the pmf**

# %% [markdown]
# > **Since we are dealing with a product based dataset the quantity column or the quantity variable is a discrete variable**
#
# > <u><font color = "yellow">The probability mass function (PMF) calculates the probabilities based on the counts or frequencies of each value in a dataset.</font></u>
#
# > In the context of a discrete random variable, the PMF assigns probabilities to each possible value that the variable can take on. These probabilities are typically determined by dividing the count or frequency of each value by the total count of all values in the dataset.
#
# > in a PMF plot, the y-axis represents the probability of obtaining each value in the dataset. Each bar's height corresponds to the probability assigned to that value by the PMF.

# %%
sales_data = pd.read_excel("C:/Users/leste/OneDrive/Desktop/College notes/Business analytics/Datasets for FBA and BI/SampleSuperstore_US.xlsx", parse_dates=["Date"])
sales_data.head(2)
# Out:
#    S.No       Date     Ship Mode   Segment        Country       City  \
# 0     1 1990-01-01  Second Class  Consumer  United States  Henderson
# 1     2 1990-02-01  Second Class  Consumer  United States  Henderson
#
#       State Region   Category Sub-Category   Sales  Quantity  Discount  \
# 0  Kentucky  South  Furniture    Bookcases  261.96       2.0       0.0
# 1  Kentucky  South  Furniture       Chairs  731.94       3.0       0.0
#
#      Profit   `
# 0   41.9136 NaN
# 1  219.5820 NaN

# %%
sales_quant = sales_data[["Quantity"]]

# %%
sales_quant = sales_quant.value_counts().to_frame().reset_index()

# %%
sales_quant.columns = ["Quantity", "Frequency"]

# %%
sales_quant["PMF"] = sales_quant["Frequency"]/sales_quant["Frequency"].sum()

# %%
sales_quant
# Out:
#     Quantity  Frequency       PMF
# 0        3.0         94  0.237374
# 1        2.0         92  0.232323
# 2        4.0         51  0.128788
# 3        5.0         36  0.090909
# 4        1.0         33  0.083333
# 5        6.0         30  0.075758
# 6        7.0         30  0.075758
# 7        8.0         12  0.030303
# 8        9.0          9  0.022727
# 9       10.0          3  0.007576
# 10      13.0          2  0.005051
# 11      14.0          2  0.005051
# 12      11.0          1  0.002525
# 13      12.0          1  0.002525

# %%
sns.barplot(data = sales_quant, x = "Quantity", y= "PMF")
# Out:
# <AxesSubplot: xlabel='Quantity', ylabel='PMF'>

# %% [markdown]
# Cummalative distributive function(cdf) for discrete random variables

# %%
sales_quant["CDF"] = sales_quant["PMF"].cumsum()

# %% [markdown]
# > In the resulting dataset after we calculate the cummalative sum of the PMF we get the cummaltive density function.
#
# > **<u><font color = 'yellow'>For example we take the quantity 7 we can see that the cummalative density value is 0.924242 which means there is approximately 92% probability of getting a value less than or equal to 7</font></u>**

# %%
sales_quant
# Out:
#     Quantity  Frequency       PMF       CDF
# 0        3.0         94  0.237374  0.237374
# 1        2.0         92  0.232323  0.469697
# 2        4.0         51  0.128788  0.598485
# 3        5.0         36  0.090909  0.689394
# 4        1.0         33  0.083333  0.772727
# 5        6.0         30  0.075758  0.848485
# 6        7.0         30  0.075758  0.924242
# 7        8.0         12  0.030303  0.954545
# 8        9.0          9  0.022727  0.977273
# 9       10.0          3  0.007576  0.984848
# 10      13.0          2  0.005051  0.989899
# 11      14.0          2  0.005051  0.994949
# 12      11.0          1  0.002525  0.997475
# 13      12.0          1  0.002525  1.000000

# %%
# Sort the DataFrame by Quantity values
sales_quant.sort_values('Quantity', inplace=True)

fig, ax1 = plt.subplots()

# Plot the CDF as a bar plot
ax1.bar(sales_quant['Quantity'], sales_quant['CDF'], alpha=0.5, color='b')
ax1.set_xlabel('Quantity')
ax1.set_ylabel('CDF', color='b')
ax1.tick_params('y', colors='b')

# Create a second y-axis for the PDF
ax2 = ax1.twinx()
ax2.plot(sales_quant['Quantity'], sales_quant['PMF'], marker='o', color='r')
ax2.set_ylabel('PDF', color='r')
ax2.tick_params('y', colors='r')


plt.title('CDF and PDF')
plt.show()

# %% [markdown]
# > **From the above graph the PMF and CDF peak at the quantity 7 and then fall**

# %% [markdown]
# ## Probability density function and Cummulative distributive function (continous) or known and random variables

# %% [markdown]
# > `Density` refers to the concentration or distribution of data points in a given range or interval. It provides information about how values are spread out within a dataset.
#
# > **`Continous distributions are represented by PDF as the no. of outcomes we can get in a continous distribution is basically infinite`**
#
# > In the probability formula of **`P(X) = No. of favourable outcomes / all outcomes`**
#
# > The probability of getting a single value in a continous distribtution is **`1/infinite which is close to 0`**
#
# > As the denominator gets the bigger the value gets close to 0
#
# > So thats why the **`probability of getting a single values in a continous distribtution is 0`**
#
# > ***Eg: Given the probability of a runner running  a mile in less than 6 mintes is equal to the probability of him running the mile in at most 6 minutes. Since time is continuous the probability of him running the mile in exactly 6 minutes is 0.***
#
# > The PDF (Probability Density Function) itself does not give actual probabilities for specific values of a continuous random variable. Instead, it provides a relative measure of likelihood or the probability density.
#
# >In a probability density function (PDF), if the curve peaks at a certain value (such as 400 in the below graph), `it indicates that this value has the highest relative likelihood or probability density in the distribution. The PDF curve gradually decreases on both sides of the peak, representing the decreasing likelihood of obtaining values farther away from the peak.`
#
#
# > `When you calculate the cumulative distribution function (CDF) based on the PDF, the CDF starts at zero and increases as you move along the x-axis. The CDF represents the cumulative probability of obtaining values up to a given point. In other words the cumulative distribution function calulates the probability of obtaining a given value or less than that value`
#
# > `To get the probability  of obtaining values higher than the given value we do 1-cdf`
#
# > In the scenario you described, if the PDF curve peaks at 2000 and then the CDF curve begins to straighten out after that value, it suggests that the probability of obtaining values beyond 2000 is relatively low. As you move beyond the peak, the probabilities accumulate more slowly, indicating a lower probability density and decreasing likelihood of observing values further away from the peak.
#
# >**<font color = "yellow">So, whether the variables are known or random, the PDF formula and the resulting plot depend on the mean and standard deviation of the distribution. These parameters provide information about the central tendency and spread of the distribution, which are crucial in determining the shape and characteristics of the PDF.**</font>

# %% [markdown]
# ### Known variables

# %%
plt.hist(sales_data.Sales , density= True)#pdf of known values
# Out:
# (array([1.96123099e-03, 1.56204238e-04, 9.83508165e-05, 2.89267107e-05,
#         1.73560264e-05, 1.15706843e-05, 0.00000000e+00, 1.73560264e-05,
#         0.00000000e+00, 5.78534215e-06]),
#  array([1.248000e+00, 4.366400e+02, 8.720320e+02, 1.307424e+03,
#         1.742816e+03, 2.178208e+03, 2.613600e+03, 3.048992e+03,
#         3.484384e+03, 3.919776e+03, 4.355168e+03]),
#  <BarContainer object of 10 artists>)

# %%
# Calculate CDF
values, counts = np.unique(sales_data.Sales, return_counts=True)
probs = counts / len(sales_data.Sales)
cdf = np.cumsum(probs)

# Plot CDF
plt.plot(values, cdf, marker='o', linestyle='-', drawstyle='steps-post')
plt.xlabel('Values')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) of Known Dataset')
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# ### Random variables

# %%
from scipy.stats import norm #pdf of random variables with a given range from (min to max) , mean and standard deviation
x = np.linspace(min(sales_data.Sales), max(sales_data.Sales), len(sales_data.Sales))
plt.plot(x, norm.pdf(x, sales_data.Sales.mean(), sales_data.Sales.std()))

# %%
plt.plot(x, norm.cdf(x, sales_data.Sales.mean(), sales_data.Sales.std()))

# %%
fig, ax1 = plt.subplots(figsize=(9, 6))

# Instantiate a second axes that shares the same x-axis
ax2 = ax1.twinx()

# Set the limits of the new axis
ax2.set_ylim(0, 1.5)

# Plot your two lines on different y-axes
ax1.plot(x, norm.pdf(x, sales_data.Sales.mean(), sales_data.Sales.std()))
ax2.plot(x, norm.cdf(x, sales_data.Sales.mean(), sales_data.Sales.std()))

plt.show()

# %%
sns.histplot(sales_data.Sales, stat= "density",)
# Out:
# <AxesSubplot: xlabel='Sales', ylabel='Density'>

# %% [markdown]
# ### Cummulative Distribution Function and Percentage Point Function
#
# > The `ppf` is the inverse of the `cdf`
#
# > The `cdf or the cumulative distribution function calculates the cummulative probability` of a given value or less with the given mean and standard deviation
#
# > The `ppf or the percent point function` gives the value from the cumulative distribution function or the cdf
#
# > The cumulative distribution function (CDF) can accept either a `random variable` or a Z-score value.
#
# > When you use the CDF function, you can provide a `random variable` as an input, and it will return the cumulative probability up to that value. For example, scipy.stats.norm.cdf(20, mean, std_dev) would give you the cumulative probability of getting a value less than or equal to 20 in a normal distribution with a given mean and standard deviation.
#
# > Alternatively, you can provide a Z-score value to the CDF function. The Z-score represents the number of standard deviations away from the mean a specific value is. For example, scipy.stats.norm.cdf(z) would give you the cumulative probability up to the Z-score value z in a standard normal distribution.
#
# > In summary, the CDF function in scipy.stats.norm can accept either a `random variable` or a Z-score value, depending on the context and distribution you are working with.
#
# > <font color = "yellow">**The default behavior for the scipy.stats.norm functions, including cdf(), pdf(), and ppf(), assumes a standard normal distribution with a mean of 0 and a standard deviation of 1**</font>.

# %% [markdown]
# ### Finding the CDF and the PPF with random variables with mean and standard deviation from the sales variable

# %%
scipy.stats.norm.ppf(0.37510289769245264, sales_data.Sales.mean(), sales_data.Sales.std())
# Out:
# 80.00000000000003

# %%
scipy.stats.norm.cdf(80, sales_data.Sales.mean(), sales_data.Sales.std())
# Out:
# 0.37510289769245264

# %% [markdown]
# ### Finding the CDF and the PPF with Z-score values with mean and standard deviation from the sales variable

# %%
z_score = (200-sales_data.Sales.mean())/sales_data.Sales.std()
z_score
# Out:
# -0.07579340240463742

# %%
cdf_value = scipy.stats.norm.cdf(z_score, sales_data.Sales.mean(), sales_data.Sales.std())

# %%
scipy.stats.norm.ppf(cdf_value, sales_data.Sales.mean(), sales_data.Sales.std())
# Out:
# -0.07579340240465626

# %%
X_value = (z_score*sales_data.Sales.std())+sales_data.Sales.mean()
X_value
# Out:
# 200.0

# %% [markdown]
# ### Calculating the cummulative probability between two values

# %%
scipy.stats.norm.cdf(2000, loc = sales_data.Sales.mean(), scale = sales_data.Sales.std())
# Out:
# 0.9998165579432533

# %%
scipy.stats.norm.cdf(1000, loc = sales_data.Sales.mean(), scale = sales_data.Sales.std())
# Out:
# 0.9383867044574769

# %%
scipy.stats.norm.cdf(2000, loc =  sales_data.Sales.mean(), scale = sales_data.Sales.std()) - scipy.stats.norm.cdf(1000, loc =  sales_data.Sales.mean(), scale = sales_data.Sales.std())
# there is a 6% chance of obtaining values between 2000 and 1000 or less
# Out:
# 0.06142985348577645

# %% [markdown]
# ### Difference between with and without replacement
#
# > `"With replacement"` means the item is selected and then replaced back into the population before the next selection. the probabilities remain the same for each selection.
#
# >> **`With Replacement`**:
# If you select candies "with replacement," it means that after each selection, you put the candy back into the bag before making the next selection. In this case, the candy you selected is replaced back into the bag, and the total number of candies remains the same for subsequent selections.
# For example, you reach into the bag and randomly select one candy. Let's say you get a red candy. You put it back into the bag and mix it up. Then, you reach in again and randomly select another candy. This process of selecting and replacing is called "with replacement
#
# > `"Without replacement" `means the item is selected and not replaced, resulting in a change in probabilities for subsequent selections as the population size decreases.
#
# >> **`Without Replacement`**:
# If you select candies "without replacement," it means that after each selection, you do not put the candy back into the bag. As a result, the total number of candies decreases for subsequent selections.
# For example, you reach into the bag and randomly select one candy. Let's say you get a red candy. However, this time, you don't put it back into the bag. Now, there are only 9 candies left in the bag. Then, you reach in again and randomly select another candy

# %% [markdown]
# ### Uniform distribution
#
# > **`All outcomes are equally likely which means the probability of each individual outcome is equally likely`**
#
# > Mean and variance are not interpretable in the case of the uniform distribution
#
# > It is a discrete distribution

# %% [markdown]
# ## Binomial distribution
#
# >  **`The binomial distribution is specifically designed to model situations where there are only two possible outcomes, often referred to as    "success" and "failure." These outcomes are mutually exclusive, meaning that only one of them can occur in a single trial.`**
#
# > **`The trial can have one outcome which can be success or failure but the difference between the bionomial distribution and the bernouli's distribution is that the bionomial distribution takes multiple trials or iterations.`**
#
# > In other words `bernouli's distribution is used when there is only one trial` and `bionomial distribution is used when there are multiple trials`
#
# > Keep in mind that the trial has a possibility of only `two outcomes`

# %% [markdown]
# > It deals with `discrete variables` which means it uses the PMF function to calculate the individiual probability and CDF to calculate the cummulative probability.
#
# > Prequisites for the binomial distribution
# >>  1. There are two potential outcomes per trial
#
# >>  2. The probability of success (p) is same across all trials. eg: There is 50% probability to get heads or tails.
#
# >>  3. The number of trials(n) is fixed
#
# >>  4. Each trial is independent which means the outcome of one trial doesn't affect the probability of the other trial.
#
#
# > Parameters of the `binom` function
# >>  1. **`n`** =  Number of trials to be conducted as per the problem.
#
# >>  2. **`p`** =  The probability of success of said statistical outcome.
#
# >>  3. **`k`** =  Probability of observing `k` observations in the problem or distribution
#
# >>  4. **`rvs`** = random variables
#
# >>  5. **`size`** = no. of samples to be generated
#
# >>  6. **`loc`** = shift in the distribution as per the yaxis. So if the no. of trials is 10 then the range will be (0,10). but if we specificy the loc as 2. then the range will shift by two points changing the range (2,12)
#
# > `The binomial distribution involves trials that are drawn with replacement`
#
# > **`The probability of getting a binomial event involves combinations with replacement. it is because this distribution or the equation behind it runs the combination of getting the same outcome in the given no. of trials`**

# %% [markdown]
# **Problem 1 - Studies that show colour blindness affects 8% of men. A random sample of 10 is taken.**

# %%
# setting the values
# of n and p
n = 10
p = 0.08
# defining list of r values
r_values = list(range(n + 1))
# list of pmf values
dist = [scipy.stats.binom.pmf(r, n, p) for r in r_values ]
# plotting the graph
plt.bar(r_values, dist)
plt.show()

# %%
print(scipy.stats.binom.pmf(n = 10, k = 10, p = 0.08)) # Observing the probability all 10 men being blind
# Out:
# 1.0737418240000003e-11

# %%
scipy.stats.binom.pmf(n = 10 , k = 10 , p =1 - 0.08) #Observing no men are colour blind. Since the percentage of colorblindness is 8% we're checking 
# of no colorblindness which is 1-probability of colorblindness
# Out:
# 0.4343884542236323

# %%
scipy.stats.binom.pmf(n = 10, k = 2, p =0.08)# probability of observing two men who are colorblind
# Out:
# 0.14780703546361773

# %%
1 - scipy.stats.binom.cdf(n = 10, k = 1, p = 0.08)#probability of observing at least 2 men who are color blind 
#in other words two or more people who are color blind or minimum 2.
# Out:
# 0.18788245514712265

# %% [markdown]
# **Problem 2 - Considering coin tosses**

# %%
n = 10
p = 0.5 
k_values = list(range(n+1))
dist = [scipy.stats.binom.pmf(n = n, k = k, p = p) for k in k_values]

plt.bar(k_values, dist)
plt.show()

# %%
scipy.stats.binom.pmf(n = 10, k = 5, p=0.5)#probability of getting  5 heads or 5 tails out of 10 flips with a 50% probability
# Out:
# 0.24609375000000003

# %%
scipy.stats.binom.pmf(n = 5, k = 3, p = 0.6)#probability of seeing an increase in 3 days with a 60% probabilty out of 5 days. Out of the 5 days 
#Any of the 3 days can witness an increase. So combinations with replacements have to take place
# Out:
# 0.3455999999999997

# %%
scipy.stats.binom.cdf(n= 10 , k = 5 , p = 0.5)#probability of getting  5 heads or 5 tails or less out of 10 flips with a 50% probability
#or getting at least 5 heads or 5 tails whichever it is (in this case only )
# Out:
# 0.623046875

# %%
scipy.stats.binom.ppf(n = 10, p = 0.5, q= 0.623046875)# returns the vaulue k - k meaning the the probability of said obeservations in give no. of trials with a percentage of give success or failure
#ppf is the inverse of the cdf
#q is the parameter given to know how many observations of k we get from the given event
# Out:
# 5.0

# %% [markdown]
# ## Poisson distribution
#
# > The Poisson distribution is a discrete probability distribution that models the number of events occurring in a fixed interval of time or   space when the events happen independently and at a constant rate. It is often used to model rare events that occur randomly, such as the number of phone calls received at a call center in a given hour or the number of accidents on a road in a day.

# %% [markdown]
# > 1. Its a discrete distribution which means there is no pdf function
#
# > 2. It requires two parameters `k` and `mu`
#
# > 3. The `loc` parameter allows you to shift the distribution along the x-axis. It is often used when you want to model events that start at a specific point in time or space.
#
# > 4. It is assumed that the rate at which events occur are constant

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
scipy.stats.poisson.pmf(k = 10, mu = 12)#Probability of getting exactly 10 click through sales in the first day with an average of 12 clicks on an average
# Out:
# 0.10483725588365922

# %%
1-scipy.stats.poisson.cdf(k = 9, mu = 12)
#Probability of getting at least 10 click through sales in the fist data with an average of 12 clicks per day
#in terms of statistics, the probability of getting a 10 or more
# Out:
# 0.7576078383294875

# %%
1-scipy.stats.poisson.cdf(k = 1, mu = 0.5 )
#Probability of getting more than one click through sale in the first hour (days converted to hours)
#The average of click through sales per days converted to average click through sales in the firts hour
# Out:
# 0.09020401043104986

# %%
n = 10
mu = 12 
k_values = list(range(n+1))
dist = [scipy.stats.poisson.pmf(k = k, mu = mu) for k in k_values]

plt.bar(k_values, dist)
plt.show()#Probability of getting exactly 10 click through sales in the first day with an average of 12 clicks on an averageb

# %% [markdown]
# ## Hypergeometric distribution
#
# > 1. It is a discrete distribution
#
# > 2. `Equivalent to a binomial distribution but without replacement`
#
# > 3. The probability of success changes with each draw
#
# > 4. Defined for 3 parameters `k`,`M`,`n`,`N`(in python)
# >> `M` - Total population size
#
# >> `n` - Total items of interest in the population (The category or the sample of the population we're interested)
#
# >> `N` - Sample size
#
# >> `k` - the observations from which the probability can be determined
#
# >> <font color = "yellow"><u>The sample size cannot exceed the total number of items of interest in the population</u> </font>

# %% [markdown]
# > Taking the problem of a deck of 52 cards

# %%
scipy.stats.hypergeom.pmf(k=2, M = 52, n = 13, N = 5)#the proabability of getting 2 observations from a sample of 5 in a interest sample of 13 out of the total population of 52
# Out:
# 0.27427971188475386

# %% [markdown]
# ### Exponential distribution
#
# > Inverse of Poisson distribution
#
# > While Poisson distribution looks at the probability of events in a time interval. Exponential distribution looks at the time between events
#
# >![image.png](attachment:image.png)
#
# > `Poisson distribution `represents `events per single unit of time`
#
# > `Exponential distribution` represents `time per single event`
#
# > Poisson distribution is a discrete distribution because it deals with events which are discrete in nature. While Exponential distribution is continous distribution becasue it deals with time which is continous in nature
#
# > loc parameter : Shift in the distribution,  the distribution along the x-axis, so it starts at a different point.
#
# > scale parameter : It represents the average time between events (or the average "waiting time") in the distribution
#
# >**`The principle of memorylessness`** states that, no matter how much time has passed since the event last occurred, the probability of the event happening in the future remains the same.It occurs in the exponential distribution. The future behaviour of the variable is not affected by its past behaviour
#
# > When events happen at the same time, their independence is determined by the absence of any relationship or influence between them. In other words, the probability of one event happening does not depend on the occurrence or outcome of the other event.

# %% [markdown]
# **Problem : The average number of people visiting a website is 3 per hour (Poisson problem).**
#
# **Convert to exponential problem : Hour until next arrival of the customer**

# %%
scipy.stats.expon.cdf(10,scale = 20)#Probability of the next customer arriving in within 10 minutes
#given the observation as 10 
#converting the average observation into minutes 
#1/3 of 3 hours  =  20minutes  in the parameter
#parameter = 1/lambda
# Out:
# 0.3934693402873666

# %%
1- scipy.stats.expon.cdf(30,scale = 20)#Probability of the next customer arriving after 30 minutes
#given observation is 30
#lambda or average observation is 20 minutes
# Out:
# 0.2231301601484298

# %%
#Probability of the customer arriving in exactly 15 minutes
#it is zero in reality because any event performed in a continous distribution cannot be exactly be a given time
#It can be between two points or between a point and infinity

# %% [markdown]
# # Quartiles
#
# [Why we take 1.5 times the IQR to determine the outliers in a dataset](https://towardsdatascience.com/why-1-5-in-iqr-method-of-outlier-detection-5d07fdc82097)

# %% [markdown]
# ### Access any row easily using
# `DataFrame.column[row index]`
#
# or
#
# `DataFrame["column"][row index]`

# %%
names = ["Michael", "Smith", "Jones","James", "Andrew", "Jason", "Gabriel", "Paul", "Jack", "Allison", "Peter"]
scores = [50000, 60000, 40000, 75000, 80000, 70000, 10000000, 95000, 20000, 10000002, 2000]
stats_data = pd.DataFrame({
    "Names" : names, 
    "Scores" : scores
})

# %%
stats_data
# Out:
#       Names    Scores
# 0   Michael     50000
# 1     Smith     60000
# 2     Jones     40000
# 3     James     75000
# 4    Andrew     80000
# 5     Jason     70000
# 6   Gabriel  10000000
# 7      Paul     95000
# 8      Jack     20000
# 9   Allison  10000002
# 10    Peter      2000

# %%
stats_data["Z_score"] = np.abs(stats_data["Scores"] - stats_data["Scores"].mean())/stats_data["Scores"].std()

# %%
stats_data
# Out:
#       Names    Scores   Z_score
# 0   Michael     50000  0.450617
# 1     Smith     60000  0.448131
# 2     Jones     40000  0.453102
# 3     James     75000  0.444403
# 4    Andrew     80000  0.443160
# 5     Jason     70000  0.445645
# 6   Gabriel  10000000  2.022555
# 7      Paul     95000  0.439431
# 8      Jack     20000  0.458073
# 9   Allison  10000002  2.022555
# 10    Peter      2000  0.462547

# %% [markdown]
# > Finding outliers using a function

# %%
def retrieve_outliers(df):
    threshold = 2
    mean = np.mean(df)
    std = np.std(df)
    outliers = [i for i in df if np.abs(i - mean)/std > threshold]
    return outliers

# %% [markdown]
# > The `np.absolute` function does take negative numbers into account, but it ignores their sign.
# It focuses only on the distance or magnitude of the number from zero. So, whether the number is positive or negative, np.absolute will give you the positive value or the distance from zero.
#
# >> If you give np.absolute the number -5, it will return 5 (ignoring the negative sign).
# >>If you give it the number 3, it will return 3 (as it is already positive).
# >>If you give it -2.7, it will return 2.7 (disregarding the negative sign).
# >>And if you give it zero, it will return zero (as the distance from zero is zero).
# >>In summary, the np.absolute function takes into account both positive and negative numbers but provides only the positive distance or magnitude from zero.

# %%
retrieve_outliers(stats_data["Scores"])
# Out:
# [10000000, 10000002]

# %%
stats_data.describe()
# Out:
#              Scores    Z_score
# count  1.100000e+01  11.000000
# mean   1.862909e+06   0.735474
# std    4.023175e+06   0.636384
# min    2.000000e+03   0.439431
# 25%    4.500000e+04   0.445024
# 50%    7.000000e+04   0.450617
# 75%    8.750000e+04   0.460310
# max    1.000000e+07   2.022555

# %% [markdown]
# ### Removing outliers using the percentile

# %% [markdown]
# So what we are doing here is we are removing the value or setting the new dataframe with the values that are below the 99 percentile that means that given value that we got for the 99th percentile we are removing that from the dataframe because its an outlier.

# %% [markdown]
# By default the interpolation for qunatile is linear for the function
#
# <font color = "orange">**df.quantile(q = "percentile specificied by the user", axis = "default 0", numeric_only = True, interpolation = "linear")**</font>
#
#
# > if i give interpolation as `higher` than it gives the value higher than the given value specified by the user
# > if i give interpolation as `lower` than it gives the value lower than the given value specified by the user

# %% [markdown]
# # Correlation and Covariance

# %% [markdown]
# `Pearson's correlation` and `Spearman's correlation` are both statistical measures used to quantify the relationship between two variables. However, they differ in terms of the type of data they are suitable for and how they handle outliers.
#
# **Pearson's correlation**:
#
# >Pearson's correlation coefficient measures the strength and direction of a linear relationship between two continuous variables.
#
# > <u>It assumes that the relationship between the variables is linear and follows a specific pattern.</u>
#
# > It is sensitive to both the strength and direction of the relationship.
#
# > Outliers can have a significant impact on Pearson's correlation. A single outlier with extreme values can distort the correlation coefficient and make it appear stronger or weaker than it actually is.
#
#
# **Spearman's correlation**:
#
# > Spearman's correlation coefficient measures the strength and direction of a monotonic relationship between variables.
#
# > It does not assume a linear relationship but looks for a consistent monotonic trend (either increasing or decreasing) between the variables.
#
# > It is based on the ranks of the data rather than the actual values.
#
# > Spearman's correlation is less sensitive to outliers compared to Pearson's correlation. Outliers have less influence because the focus is on the order or ranks of the data rather than their actual values.
#
# In summary, Pearson's correlation is appropriate for assessing linear relationships between continuous variables, but it is sensitive to outliers. Spearman's correlation, on the other hand, is suitable for assessing monotonic relationships and is more robust against outliers.
#
# <font color = "yellow"> <u>A monotonic relationship means that as the values of one variable increase, the ranks of the corresponding values of the other variable also tend to increase (monotonic increasing) or decrease (monotonic decreasing).</u></font>

# %% [markdown]
# # Euclidean distance
#
#  > Euclidean distance is a mathematical concept that helps us measure the straight-line distance between two points in space. It's like the shortest distance between two points, as if you could draw a straight line directly from one point to the other.
#
#  > Euclidean distance is a metric that helps measure the similarity or dissimilarity between data points. By calculating the Euclidean distance between two data points, we can quantify how close or far apart they are from each other.
#
#  > In terms of similarity, when the Euclidean distance between two data points is small, it indicates that they are more similar to each other. It means that their feature values or characteristics are closer in magnitude or share similar patterns.
#
#  > On the other hand, when the Euclidean distance between two data points is large, it suggests that they are more dissimilar. It implies that their feature values or characteristics are farther apart in magnitude or have different patterns.
#
#  > This notion of similarity and dissimilarity is useful in various data science tasks. For example, in clustering algorithms, we can group similar data points together by minimizing the Euclidean distance between them. In classification algorithms, we can use the Euclidean distance to identify the nearest neighbors of a data point and make predictions based on their similarities.
#
#  > So, by leveraging the Euclidean distance, we can quantify and understand the relationships between data points, allowing us to make informed decisions and gain insights from the data.

# %% [markdown]
# # Euclidean distance in standardization and normalization
#
#  > Euclidean distance is often used in normalization and standardization techniques to preprocess data before applying machine learning algorithms. These techniques aim to bring the features of the data to a similar scale or distribution, which can improve the performance and effectiveness of certain algorithms.
#
#  >Normalization (also known as feature scaling) is the process of rescaling the features of a dataset to a common range. One common normalization technique is min-max scaling. In this approach, the values of each feature are transformed to a range between 0 and 1.
#  Euclidean distance can be affected by the scale of the features. When performing normalization, the Euclidean distance between data points becomes more meaningful because all features are on a similar scale. This allows for a fair comparison of the distances across different features.
#
#  > For example, let's say you have a dataset with two features: age and income. Age is measured in years (ranging from 0 to 100) and income is measured in dollars (ranging from 0 to 100,000). If you calculate the Euclidean distance directly, income will dominate the distance calculation due to its larger range. However, by normalizing both features, they will be on the same scale (0 to 1), ensuring that both features contribute equally to the Euclidean distance calculation.
#
#
#  > `Standardization (or z-score normalization) transforms the features of a dataset to have zero mean and 1 standard deviation`. Its is a special kind of transformation
#
#  > **`A Tranformation is a way to alter every element in the distribution by adding , subtracting , multiplying and dividing every element in the distribution`**
#
#  > This means that the mean of each feature is subtracted and divided by its standard deviation.
#
#  > **`In this case the expected value is equal to the mean only when we calculate the mean in a probability distribution`**
#
#  > In addition to the 68, 95 and 99.7 in a normal distribution stating that
#  >> 68% of the data lies within one standard deviation of the mean (mean - standard deviation)
#
#  >> 95% of the data lies within two standard deviation of the mean (mean - 2*standard deviation)
#
#  >> 99.7% of the data lies within three standard deviations of the mean (mean - 3*standard deviation)
#
#  >> Z-score = X- mean / standard deviation
#
#  > **<font color = "yellow">If the value x = mean + 2.3*standard deviations  then its equivalent to z-score = 2.3</font>**
#
#  > Commonly used values of the cdf are with respect to the standard normal distribution is known as Z-score table
#
#  > **<font color = "yellow">A crucial factor to remember in a normal distribution is that it requires  a lot of data. Standardisation works well when the data follows a normal distribution. But we can't always anticipate it that way. If we use normal distribution on a small sample we don't account for the outliers which might drastically affect our analysis </font>**
#
#  > Euclidean distance can also be influenced by the variance of the features. Standardization helps to normalize the spread or distribution of the features, making them more comparable in terms of their distance calculation.
#
#  > By standardizing the features, the Euclidean distance is less sensitive to the scale and more focused on the relative positions or patterns of the data points. This can be beneficial when dealing with features that have different units or scales.

# %% [markdown]
# # Hypothesis Testing
#
# ### Mutually exclusive statements
# > A mutually exclusive statement in statistics refers to two or more events or categories that cannot occur simultaneously. It means that if one event or category happens, the others cannot happen at the same time. In other words, these events or categories are mutually exclusive or disjoint
#
# > For example, let's consider a simple situation where we have two categories: "heads" and "tails" for flipping a coin. If the coin is flipped and it lands on "heads," it cannot simultaneously be "tails." Similarly, if it lands on "tails," it cannot be "heads" at the same time. These two categories, "heads" and "tails," are mutually exclusive because only one of them can occur in a single coin flip
#
# > In statistics, mutually exclusive events or categories are important because they allow us to define and analyze probabilities. If events are mutually exclusive, the probability of any one of them occurring can be calculated by summing the probabilities of each individual event.
#
#
# ### Steps to Hypothesis Testing
# > Make the intial basic assumption
#
# >> H0 (null hypothesis)
#
# >> H1 (alternate hypothesis)
#
# > Collect the data necessary
#
# > Collect the evidence to accept or reject the null hypothesis
#
# ### Confustion matrix for hypothesis testing
#
#
# <img src = "https://i1.wp.com/dataaspirant.com/wp-content/uploads/2020/08/3_confusion_matrix.png?ssl=1" style = "width:600px; height:300px;">
#
# > True Positive: When the predicted outcome is True and the actual outcome is also True.
#
# > False Positive: When the predicted outcome is True but the actual outcome is False.
#
# > True Negative: When the predicted outcome is False and the actual outcome is also False.
#
# > False Negative: When the predicted outcome is False but the actual outcome is True.
#
#
#
#
#
# <img src="https://pepgra.com/wp-content/uploads/2020/07/pep2-300x235.jpg" style="width:600px; height:300px;">
#
#
# > **`Type I Error`** (False Positive): A Type I error occurs when the null hypothesis is rejected, even though it is actually true. In other words, it's an incorrect rejection of a true null hypothesis. This error represents a false positive result, where the test concludes that there is a significant effect or relationship when, in fact, there is none. The probability of committing a Type I error is denoted by α (alpha) and is set by the researcher in advance as the significance level. This case occurs when there is lack of evidence to prove the truth of the null hypothesis. This leads to the rejection of the null hypothesis and adoption of the alternative hypothesis.
#
# > **`Type II Error`** (False Negative): A Type II error occurs when the null hypothesis is not rejected, even though it is false. In other words, it's an incorrect acceptance of a false null hypothesis. This error represents a false negative result, where the test fails to detect a significant effect or relationship that actually exists. The probability of committing a Type II error is denoted by β (beta). This case occurs when there is evidence to prove that the null hypothesis is False but is claimed to be True. In other words the alternate hypothesis is rejected even when it is claimed to be True.

# %% [markdown]
# ### Degrees of freedom
#
# [Degrees of Freedom](https://www.geeksforgeeks.org/degrees-of-freedom/)
#
# ### Degrees of Freedom for chi-square test
# <font size = 5 color = "yellow"><u>Very important concept</u></font>
#
# > The degrees of freedom refer to the number of independent pieces of information available in a dataset
#
# >It indicates the number of independent pieces of information that are available for estimation, inference, or analysis.
#
# >In some cases, having information on certain independent pieces can help you determine related values or make inferences about the population. However, it's important to note that degrees of freedom themselves do not directly determine or infer specific values. They simply indicate the number of independent pieces of information available for analysis or estimation.
#
# ![image.png](attachment:image.png)
#
# > In the above figure for example if we know the value of Near bleached corals from the P- category to be 31 then we can easily determine the unbleached corals from the same category as the total for that category is already given to be 50. So given the value 31 we can easily determine the other value to be 19. So that means we can take bleached corals from the P-category as an independant piece of information. Same applies if we knew the other value (19), which will make the other value (31) easy to determine since we know the total. This is from a vertical calculation view
#
# > Since the total of Near bleached corals is 60 i know one independent variable to be 31 but i need to know one more to determine the last one to have the total to be 60. So if i know the second value as well then i can easily determine the last value as well which make it two independent pieces of information.
#
# > As in the terms of the formula to be (no. of row values -1)(no. of col values -1)
# >> Since i needed to know two independent pieces of information from the row to determine the third one i can easily also determine the respective column value with those two independent pieces of information. depending on the matrix of the distribution

# %% [markdown]
# ### P_value and Significance value
#
# > The `p-value` tells you how likely it is that your results happened by chance.
#
# > The `significance value` is a threshold you set to decide whether your results are strong enough to reject the idea of chance and support a meaningful effect.
#
# > `The significance value (also known as the significance level or alpha) is a predetermined threshold or limit that you set to determine when to reject the null hypothesis. It acts as a boundary for the p-value`

# %% [markdown]
# ### Different types of Hypothesis testing and P-value
#
# > In statistics, a `p-value is a measure that helps us determine the strength of evidence against a specific hypothesis`. It is used to assess whether an observed result is statistically significant or if it could have occurred by chance.
#
# > The `p-value` is the probability of getting a sample as or more extreme than our own. extreme means both ends of the distribution
#
# > To put it simply, the `p-value tells us the probability of obtaining the observed data (or more extreme results) if the null hypothesis were true.`
#
# > If the `p-value is small (typically less than 0.05), it suggests that the observed data is unlikely to occur if the null hypothesis were true.` In this case, we reject the null hypothesis and conclude that there is evidence to support an alternative hypothesis. On the other hand, if the `p-value is large, it indicates that the observed data could reasonably occur even if the null hypothesis were true, and we fail to reject the null hypothesis`
#
# > **`Note` : <font color = "yellow"> The P-value tells us the probability of observing the results based on a random chance assuming the null hypothesis is true</font>**
#
# > If the p-value of certain test fall at the extreme ends or tail ends of a normal distribution which is -2.5 and +2.5% of the data then we reject the null hypothesis.
#
# > `T-test` - The t-test is a statistical test that is used to compare the means of `two groups and determine if there is a significant difference between them`. It is commonly used when you have two groups of numerical data and want to assess if the means of these groups are statistically different from each other.
#
# > `Chi Square test ` - The chi-square test is used when we have categorical data and want to determine if `there is a significant association or relationship between two categorical variables`. It helps us understand if the observed data differs significantly from what we would expect by chance.
#
# > `One sample propotion test` - The one-sample proportion test is used when you have a `categorical variable`, which means the data falls into distinct categories or groups. This test specifically focuses on analyzing and comparing proportions or percentages associated with those categories.the one-sample proportion test is typically used with respect to a `single categorical variable`.
#
# > `ANOVA test` - The ANOVA test is used when you have a combination of a `categorical independent variable (often referred to as a factor) and a numerical dependent variable.` It allows you to assess if there are significant differences in the means of the dependent variable across the different levels or groups of the independent variable.
#
# In an ANOVA analysis, the categorical variable is used to define the groups or levels, and the numerical variable is the outcome or measurement that you want to compare. It is used when the categorical variable has more than two categorical.
#
#
# > Mean and proportion are different
#
# >>`Mean mostly has to do with the quantitative variables` whereas `proportion is more on the categorical or qualitative side`
#
# >><font color = "yellow"><u>Proportion can be categorical such as (red , green , blue) or categorical continous such (1-10, 10-20 )</u></font>

# %% [markdown]
# ## T-distribution
#
# > `We use T-distribution when` :
#
# >> 1. The underlying distribution is a normal distribution
#
# >> 2. The population standard deviation is unknown
#
# >> 3. When the sample size is too small for the central limit theorem to apply (typically less than 30)
#
# >> 4. The t-distribution formula is used to calculate the t-score or t-statistic. The t-score is obtained by applying the t-distribution formula to the sample data.
#
# >> 5. When the population distribution must be uni-modal and skewed
#
# > `The smaller the sample size the more uncertainity a distribution is`
#
# >  It is specifically designed for situations where the population standard deviation is unknown and needs to be estimated from the sample data
#
# >  `As the sample size increases, the t-distribution approaches the standard normal distribution (z-distribution). This is known as the Central Limit Theorem.`
#
# > The t-distribution is used when the population standard deviation is unknown, and it takes into account the variability in small sample sizes. As the sample size increases, the t-distribution becomes closer to the standard normal distribution.
#
# > t-score (t-statistic) indirectly estimates the standard deviation through the standard error, and the p-value calculates the probability of obtaining a test statistic as extreme as, or more extreme than, the one observed.
#
# > `As the sample size increases, the t-distribution approaches and approximates the standard normal distribution (z-distribution). This is known as the Central Limit Theorem.` OR `As the degrees of freedom increases, the t-distribution becomes closer to the normal distribution`

# %% [markdown]
# **One-Tailed Test:**
#
# - In a one-tailed test, we are interested in examining the effect or difference in one specific direction.
# - It focuses on whether the observed data is significantly greater or significantly smaller than what is expected under the null hypothesis.
# - `Imagine you are investigating whether a new medication improves test scores. A one-tailed test would determine if the scores are significantly higher due to the medication, ignoring the possibility of scores being significantly lower or vice versa`
#
# **Two-Tailed Test:**
#
# - In a two-tailed test, we are interested in examining the effect or difference in both directions.
# - It considers whether the observed data is significantly different, regardless of whether it is greater or smaller than what is expected under the null hypothesis.
# - `Using the same example of the medication and test scores, a two-tailed test would determine if the scores are significantly different from what is expected, without specifying whether they are higher or lower.`
#
# In summary, a one-tailed test focuses on detecting a significant difference in one specific direction, while a two-tailed test is interested in detecting a significant difference regardless of the direction.

# %% [markdown]
# ### One Sample T- test
#
# > The one-sample t-test is used to determine if the mean of a `single sample significantly differs from a specific value or a hypothesized population mean`
#
# > <font color = "yellow"><u> In a one-sample test, you conduct a statistical test using a sample from a population to make inferences about the population itself.</u></font>
#
# > Use the `ttest_1samp` module from the stats package to make inferences about the population from a sample

# %%
from scipy.stats import ttest_1samp

# %%
len(sales_data.Sales)
# Out:
# 397

# %%
np.mean(sales_data.Sales)
# Out:
# 237.49447682619646

# %%
age_sample1 = np.random.choice(sales_data["Sales"], 40) # sample size of 40 
age_sample2 = np.random.choice(sales_data["Sales"], 40)

# %%
age_sample1.mean()
# Out:
# 380.32935

# %%
age_sample2.mean()
# Out:
# 140.34357500000002

# %%
ttest_1,p_value1 = ttest_1samp(age_sample1,popmean = np.mean(sales_data.Sales))
ttest_2,p_value2 = ttest_1samp(age_sample2,popmean = np.mean(sales_data.Sales))

# %%
p_value1
# Out:
# 0.19059080985865615

# %%
p_value2
# Out:
# 0.025451026737945734

# %%
def check_pvalue(p_value):      
    if p_value  < 0.05:
        print("We're rejecting the null hypothesis") #My alternate hypothesis being that there is a significant difference in the mean of the sales
    else: 
        print("We're accepting the null hypothesis")#My null hypothesis being that there is no significant difference in the mean of the sales

# %%
check_pvalue(p_value1)
# Out:
# We're accepting the null hypothesis

# %%
check_pvalue(p_value2)
# Out:
# We're rejecting the null hypothesis

# %% [markdown]
# ### Two sample T-test
#
# > A two-sample t-test is a statistical test used to compare the `means of two independent groups or samples to determine if there is a significant difference between them`. It helps to answer the question: Are the averages of two groups different from each other in a meaningful way?
#
# > We use the `t-test of the independence` module to conduct the test between two independent groups. Such as in the below example of conducting a hypothesis between two different categories of corporate and consumer samples
#
# > Use the `ttest_ind` also known as the ttest of independance between two independent groups

# %%
from scipy.stats import ttest_ind

# %%
consumer_data = sales_data.query('Segment == "Consumer"')[["Sales"]]
corporate_data = sales_data.query('Segment == "Corporate"')[["Sales"]]

# %%
consumer_data.mean(), consumer_data.var()
# Out:
# (Sales    232.94176
#  dtype: float64,
#  Sales    217771.689556
#  dtype: float64)

# %%
corporate_data.mean(), corporate_data.var()
# Out:
# (Sales    213.38479
#  dtype: float64,
#  Sales    214202.419082
#  dtype: float64)

# %%
ttest, p_value = ttest_ind(a = consumer_data, b = corporate_data, equal_var= False) # unequal variances

# %%
p_value
# Out:
# array([0.70925167])

# %%
check_pvalue(p_value)
# Out:
# We're accepting the null hypothesis

# %% [markdown]
# ### Paired T-test
#
# > The paired t-test, also known as the `paired samples t-test or dependent samples t-test`, is used when you want to `compare the means of two related or paired sample`s. <font color = "yellow"><u> It is appropriate when the data in the two samples are not independent but are somehow related or connected.</u></font>
#
# > The paired t-test is suitable when you have two related samples, such as sales data from two different years for the same set of entities
#
# > Use the `ttest_rel` because we are conducting a test between two dependant samples and making a hypthesis
#
# > The mean on its own without performing the test is not enough to prove any evidence

# %% [markdown]
# ## Alternative parameter
#
# `The "alternative" parameter can be set to either "two-sided" (default), "less," or "greater":`
#
# `"two-sided"` (default): It performs a two-tailed test, checking for a difference in both directions.
#
# `"less"`: It performs a one-tailed test for a smaller mean or difference.
#
# `"greater"`: It performs a one-tailed test for a greater mean or difference.
#
# By specifying the alternative hypothesis, you can choose the specific direction of the test based on your research question and hypothesis.
#
#
# ## Example
#
# >  Research Question: The research question is focused on whether there is any difference in the test scores between the two groups. `We are interested in finding evidence of a difference, regardless of whether Group A has higher or lower scores than Group B.It indicates a two tailed test which means regardless of the direction of whether more or less mean differences exist between Group A and Group B.`
#
# > Null Hypothesis: The null hypothesis states that there is no difference in the means of the two groups. In other words, the average test scores for Group A and Group B are equal.
#
# > Alternative Hypothesis: The alternative hypothesis is that there is a difference in the means of the two groups, without specifying the direction. It allows for the possibility that Group A could have higher or lower scores than Group B.
#
# > By conducting a two-tailed test, we consider both possibilities: Group A having higher scores or Group A having lower scores. The p-value obtained from the test will reflect the evidence for any significant difference, regardless of the direction.
#
# > If `the research question or hypothesis had specified a specific direction (e.g., "Group A has higher scores than Group B"), then a one-tailed test could be used to focus the analysis on that particular direction`

# %% [markdown]
# #### Considering the sales data from two years 1991 and 1990

# %%
from scipy.stats import ttest_rel

# %%
sales_data_1991 = sales_data.query('Year == 1991')["Sales"]
sales_data_1990 = sales_data.query('Year == 1990')["Sales"]

# %%
sales_1990  = np.random.choice(sales_data_1990, 15)
sales_1991 =  np.random.choice(sales_data_1991, 15)

# %%
ttest, p_value = ttest_rel(a= sales_1990 , b= sales_1991)

# %%
p_value
# Out:
# 0.29676961976138533

# %%
check_pvalue(p_value)
# Out:
# We're accepting the null hypothesis

# %% [markdown]
# ### Chi Square Test
#
# > <img src = https://study.com/cimages/multimages/16/chiformula1.jpg>
#
# > The formula computes the summation of the difference of the squares between the observed and the expected values divided by the expected value
#
# > Using the `chi-contingency` we function calculate the expected values from the data set (main reaon)
# > Alpha value = In the context of statistical hypothesis testing, the alpha value (α) in the chi-square test represents the significance level. It is a predetermined threshold set by the researcher that determines the level of evidence required to reject the null hypothesis. `the alpha value helps you decide how much evidence you need to say there is a significant relationship between the variables you're studying`
#
# >  If you have a test statistic that corresponds to a p-value greater than your chosen alpha value, you fail to reject the null hypothesis.

# %% [markdown]
# ### Pythonic steps to conduct chi-square tests
#
# > Use the the `pd.crossta`b function to convert the categorical variables into a numerical distribution ( based on the question)
#
# > The resulting matrix will give the observed values
#
# > Use the `chi2_contingency` function to calculate the expected values which will be needed to calculate the chi-square test statistic
#
# > Use the formula from above to calculate the `chi-square test statistic`
#
# > After that calculate the `degrees of freedom` and `determine an alpha value (mostly being 0.05) it depends on the user or organization`
#
# > Use the `chi2.ppf to find the critical value` and then use `(1-chi2.cdf) to calculate the p_value`

# %%
from scipy.stats import chi2_contingency

# %%
tips_dataset = pd.read_csv("C:/Users/leste/OneDrive/Desktop/Python files/mypythonprogrammes/Mydatafiles/Python Datasets/tips.csv")

# %%
tips_dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_table = pd.crosstab(tips_dataset["sex"], tips_dataset.smoker)
tips_table
# Out:
# smoker  No  Yes
# sex
# Female  54   33
# Male    97   60

# %%
Observed_values = tips_table.values
Observed_values
# Out:
# array([[54, 33],
#        [97, 60]], dtype=int64)

# %%
chi_val = chi2_contingency(tips_table)

# %%
chi_val
# returns the test statistic ,p_value, degrees of freedom and the expected array of values which is the same shape as the observed data
# Out:
# (0.0,
#  1.0,
#  1,
#  array([[53.84016393, 33.15983607],
#         [97.15983607, 59.84016393]]))

# %%
expected_values = chi_val[3]
expected_values
# Out:
# array([[53.84016393, 33.15983607],
#        [97.15983607, 59.84016393]])

# %% [markdown]
# > Even though the degree of freedom is calculated from the chi contingency fucntion
#
# > calculation - the pythonic way

# %%
ddof = (Observed_values.shape[0] - 1)*(Observed_values.shape[1] - 1) #Formula for degree of freedom 
# (no. of row values - 1)*(no. of column values - 1)
alpha_value = 0.05 #95% of the variance we can capture

# %%
chi_square = sum([(observed-expected)**2/expected for observed, expected in zip(Observed_values, expected_values)])
chi_square_statistic = chi_square[0] + chi_square[1]
chi_square_statistic
# Out:
# 0.001934818536627623

# %% [markdown]
# > `ppf` is the inverse of `cdf `
#
# > We found the `critical value` using the <u>`chi.ppf`</u> function
#
# > Using the <u>`chi.cdf`</u> function we can find the `p_value`

# %%
from scipy.stats import chi2

critical_value = chi2.ppf(q = 1- alpha_value, df = ddof)
chi_test_p_value = 1-chi2.cdf(x = chi_square_statistic, df = ddof)

# %%
critical_value, chi_test_p_value
# Out:
# (3.841458820694124, 0.964915107315732)

# %% [markdown]
# > <font color = "yellow">**The comparison between the chi-square test statistic and the critical value helps us determine if there is a significant deviation between the observed and expected values.**</font>
#
# > If the **`chi-square test statistic is larger than the critical value`**, it suggests that the deviation between the observed and expected values is unlikely to be explained by random chance alone. In this case, we reject the null hypothesis and conclude that there is evidence of a significant deviation or association between the variables being studied.
#
# > On the other hand, if **`the chi-square test statistic is smaller than the critical value`**, it suggests that the observed deviation could reasonably be attributed to random chance. In this case, we fail to reject the null hypothesis and conclude that there is not enough evidence to support a significant deviation or association between the variables.

# %%
if chi_square_statistic >= critical_value:
    print("Reject null hypothesis, there is a relationship between the two variables")
else: 
    print("Retain the null hypothesis, there is no relationship between the two variables given the comparison" )


if chi_test_p_value <= alpha_value:
    print("Reject null hypothesis, there is a relationship between the two variables")
else:
    print("Retain the null hypothesis, there is no relationship between the two variables")
# Out:
# Retain the null hypothesis, there is no relationship between the two variables given the comparison
# Retain the null hypothesis, there is no relationship between the two variables
