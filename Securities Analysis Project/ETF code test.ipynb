# %%
import pandas as pd 
# %run ETF_code_structure.py

# %%
equity_ETF_tickers = ["AXISGOLD.BO","ICICINIFTY.NS","HDFCSENETF.NS"]

# %%
ETF_extraction = ETF_analysis(equity_ETF_tickers, start_date = "2012-1-1" , end_date  = None)

# %%
ETF_extraction.ETF_data_extraction()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2012-02-14  2730.000000  2772.000000  2730.000000  2772.000000  2772.000000
# 2012-02-15  2744.000000  2760.000000  2705.149902  2756.659912  2756.659912
# 2012-02-16  2705.449951  2780.500000  2705.449951  2780.500000  2780.500000
# 2012-02-17  2779.000000  2779.000000  2779.000000  2779.000000  2779.000000
# 2012-02-21  2798.949951  2798.949951  2722.010010  2722.010010  2722.010010
# ...                 ...          ...          ...          ...          ...
# 2023-02-27   653.969971   653.969971   641.690002   646.849976   646.849976
# 2023-02-28   646.599976   648.909973   641.500000   642.929993   642.929993
# ...

# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
